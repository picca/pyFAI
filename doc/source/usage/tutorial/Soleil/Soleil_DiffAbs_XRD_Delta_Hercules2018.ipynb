# %% [markdown]
# ## Soleil DiffAbs XRD:
# * [Calibration](#calibration)
# * [Integration](#integration)

# %% [markdown]
# ## Calibration <a name="calibration"></a>

# %% [markdown]
# This tutorial is for the calibration of an Xpad_flat on the Soleil Diffabs Diffractometer.
#
# The calibration data is a scan on the delta motor with a CeO2 calibrant.

# %%
# %matplotlib notebook

# first the imports
from typing import Iterator, List, NamedTuple, Text, Tuple

import os
import functools

from collections import namedtuple
from math import pi

import numpy
import pylab
import pyFAI

import ipywidgets as widgets

from h5py import Dataset, File
from IPython.display import display
from numpy import ndarray
from pyFAI.gui import jupyter

# local import
from soleil import Angle, Calibrant, Calibration, CalibrationFunctions, CalibrationFrame, DatasetPathContains, DatasetPathWithAttribute, \
    Detector, Length, Parameter, Wavelength, \
    calibration, integrate, save_as_edf

# %%
# temporary until the ruch is ON
ROOT = os.path.join("/nfs", "ruche-diffabs", "diffabs-soleil", "com-diffabs", "2018", "Run2")

PUBLISHED = os.path.join("/nfs", "ruche-diffabs", "diffabs-soleil", "com-diffabs", "2018", "Run2B", "TPHercules")

# %%
# do a calibration with a well centered sample.

# TODO recuperer le point de départ à partir des ponis de référence.
# TODO ajouter le diagramme complet à la fin.
# TODO ajout du mask pour la calibration

json = os.path.join(PUBLISHED, "xrd", "calibration", "calibration.json")

distance = Length(0.644)
poni1 = Length(0.015639111692746385)
poni2 = Length(0.026262764736101073)
rot1_scale = -1
rot1_offset = Angle(-15.999503651711137)
rot2 = Angle(0.00038785472522193072)
rot3 = Angle(0)

functions = (
    CalibrationFunctions("dist", "poni1", "poni2",
                         "pi * (rot1_scale * delta + rot1_offset) / 180",
                         "rot2",
                         "rot3"),
    [Parameter[Length]("dist", distance, (distance-0.01, distance+0.01)),
     Parameter[Length]("poni1", poni1, (poni1, poni1)),
     Parameter[Length]("poni2", poni2, (poni2-0.01, poni2+0.01)),
     Parameter[float]("rot1_scale", rot1_scale, (rot1_scale-0.1, rot1_scale+0.1)),
     Parameter[Angle]("rot1_offset", rot1_offset, (rot1_offset-1, rot1_offset+1)),
     Parameter[float]("rot2", rot2, (rot2-0.1, rot2+0.1)),
     Parameter[Angle]("rot3", rot3, (rot3, rot3))]
)

def to_use(frame: CalibrationFrame) -> bool:
    return True if frame.idx in range(1,8) else False

params = Calibration(os.path.join(PUBLISHED, "xrd", "calibration"),
                     os.path.join(ROOT, "2018-03-21", "TPHercules_7.nxs"),
                     DatasetPathWithAttribute("interpretation", b"image"),
                     DatasetPathContains("scan_data/actuator_1_1"),
                     [1, 2, 3],
                     to_use,
                     Calibrant("CeO2"),
                     Detector("imxpads140"),
                     Wavelength(6.8877e-11),
                     functions
                    )

# %%
from functools import partial

def on_click_button(cmd, b):
    ! {cmd}
    
def my_cmd_button(cmd, description):
    # Click the button to open the data with silx
    button = widgets.Button(
        description=description,
        disabled=False,
        button_style='info', # 'success', 'info', 'warning', 'danger' or ''
        tooltip='Click me',
        icon='check',
        layout = widgets.Layout(width='auto')
    )

    display(button)

    button.on_click(partial(on_click_button, cmd))

    return button

# %%
silx = my_cmd_button("silx view --use-opengl-plot " + params.filename,
                     'Silx View ' + os.path.basename(params.filename))

# %%
# save all the ref as images in order to do the calibration with
# pyFAI-calib[2].
# temporary until pyFAI-calib2 can read from NeXuS files.

cmds = save_as_edf(params)
for cmd, idx in zip(cmds, params.idxs):
    my_cmd_button(cmd, 'PyFAI-calib2 ' + os.path.basename(params.filename) + " " + str(idx))

# %%
# execute the calibration

calibration(json, params)
# Out:
# Empty refinement object:
# GoniometerRefinement with 0 geometries labeled: .
# Detector Imxpad S140	 PixelSize= 1.300e-04, 1.300e-04 m
# Wavelength= 6.887700e-11m
# SampleDetDist= 6.161367e-01m	PONI= -3.507805e-02, 1.358724e-01m	rot1=-0.044207  rot2= 0.078390  rot3= -0.000000 rad
# DirectBeamDist= 618.639mm	Center: x=1254.830, y=102.827 pix	Tilt=5.155 deg  tiltPlanRotation= 60.638 deg
# Detector Imxpad S140	 PixelSize= 1.300e-04, 1.300e-04 m
# Wavelength= 6.887700e-11m
# SampleDetDist= 6.073942e-01m	PONI= -1.526742e-01, -5.070196e-02m	rot1=-0.407438  rot2= 0.258864  rot3= 0.000001 rad
# DirectBeamDist= 684.351mm	Center: x=1626.483, y=173.134 pix	Tilt=27.433 deg  tiltPlanRotation= 33.753 deg
# Detector Imxpad S140	 PixelSize= 1.300e-04, 1.300e-04 m
# Wavelength= 6.887700e-11m
# SampleDetDist= 6.441112e-01m	PONI= 1.508603e-02, 3.603602e-02m	rot1=-0.308815  rot2= 0.000814  rot3= 0.000000 rad
# DirectBeamDist= 676.095mm	Center: x=1857.856, y=120.280 pix	Tilt=17.694 deg  tiltPlanRotation= 0.153 deg
# Filled refinement object:
# GoniometerRefinement with 3 geometries labeled: TPHercules_7.nxs_1, TPHercules_7.nxs_2, TPHercules_7.nxs_3.
#
# 	label 	 tx
# TPHercules_7.nxs_1 (-3.451222685656,)
# TPHercules_7.nxs_2 (-0.45159802485419998,)
# TPHercules_7.nxs_3 (2.5487246468050002,)
# Detector Imxpad S140	 PixelSize= 1.300e-04, 1.300e-04 m
# Wavelength= 6.887700e-11m
# SampleDetDist= 6.440000e-01m	PONI= 1.563911e-02, 2.626276e-02m	rot1=-0.219009  rot2= 0.000388  rot3= 0.000000 rad
# DirectBeamDist= 659.760mm	Center: x=1304.643, y=122.269 pix	Tilt=12.548 deg  tiltPlanRotation= 0.102 deg
# Detector Imxpad S140	 PixelSize= 1.300e-04, 1.300e-04 m
# Wavelength= 6.887700e-11m
# SampleDetDist= 6.440000e-01m	PONI= 1.563911e-02, 2.626276e-02m	rot1=-0.271362  rot2= 0.000388  rot3= 0.000000 rad
# DirectBeamDist= 668.461mm	Center: x=1580.306, y=122.295 pix	Tilt=15.548 deg  tiltPlanRotation= 0.083 deg
# Detector Imxpad S140	 PixelSize= 1.300e-04, 1.300e-04 m
# Wavelength= 6.887700e-11m
# SampleDetDist= 6.440000e-01m	PONI= 1.563911e-02, 2.626276e-02m	rot1=-0.323728  rot2= 0.000388  rot3= 0.000000 rad
# DirectBeamDist= 679.285mm	Center: x=1864.193, y=122.328 pix	Tilt=18.548 deg  tiltPlanRotation= 0.070 deg
# <div id='c8a13aa5-9304-4057-afe9-c85fab943668'></div>
# <div id='385d85cb-548e-40aa-8793-e709f1ea8edd'></div>
# <div id='fff314ab-471a-407a-86f7-8d7611811f74'></div>
# Cost function before refinement: 1.75270325262e-07
# [  6.44000000e-01   1.56391117e-02   2.62627647e-02  -1.00000000e+00
#   -1.59995037e+01   3.87854725e-04   0.00000000e+00]
#      fun: 5.7851085934378249e-09
#      jac: array([  8.43960068e-10,   6.16364682e-09,   2.69478566e-08,
#         -2.68279676e-10,   1.31121097e-09,   1.54755819e-10,
#         -1.74860126e-14,   0.00000000e+00])
#  message: 'Optimization terminated successfully.'
#     nfev: 154
#      nit: 17
#     njev: 17
#   status: 0
#  success: True
#        x: array([  6.43805206e-01,   1.56391117e-02,   2.65135913e-02,
#         -9.96093297e-01,  -1.59995061e+01,  -5.59136366e-05,
#          0.00000000e+00])
# Cost function after refinement: 5.78510859344e-09
# GonioParam(dist=0.64380520621704995, poni1=0.015639111692746385, poni2=0.0265135913142076, rot1_scale=-0.99609329729560891, rot1_offset=-15.999506107308562, rot2=-5.591363662629065e-05, rot3=0.0)
# maxdelta on: rot1_scale (3) -1 --> -0.996093297296
#
#
#
#
# TPHercules_7.nxs_4
# ControlPoints instance containing 1 group of point:
# CeO2 Calibrant with 41 reflections at wavelength 6.8877e-11
# Containing 1 groups of points:
# # c ring 2: 10 points
#
# TPHercules_7.nxs_5
# ControlPoints instance containing 3 group of point:
# CeO2 Calibrant with 41 reflections at wavelength 6.8877e-11
# Containing 3 groups of points:
# # d ring 2: 10 points
# # e ring 3: 8 points
# # f ring 4: 8 points
#
# TPHercules_7.nxs_6
# ControlPoints instance containing 3 group of point:
# CeO2 Calibrant with 41 reflections at wavelength 6.8877e-11
# Containing 3 groups of points:
# # g ring 3: 8 points
# # h ring 4: 8 points
# # i ring 5: 8 points
#
# TPHercules_7.nxs_7
# ControlPoints instance containing 2 group of point:
# CeO2 Calibrant with 41 reflections at wavelength 6.8877e-11
# Containing 2 groups of points:
# # j ring 5: 8 points
# # k ring 6: 8 points
# **************************************************
# Cost function before refinement: 2.58003426744e-08
# [  6.43805206e-01   1.56391117e-02   2.65135913e-02  -9.96093297e-01
#   -1.59995061e+01  -5.59136366e-05   0.00000000e+00]
#      fun: 9.1477191738352334e-09
#      jac: array([ -3.09202227e-08,  -1.64830194e-07,   7.25588867e-09,
#          2.95651359e-09,   2.69242828e-09,  -1.42309447e-07,
#         -4.10782519e-15,   0.00000000e+00])
#  message: 'Optimization terminated successfully.'
#     nfev: 91
#      nit: 10
#     njev: 10
#   status: 0
#  success: True
#        x: array([  6.43944756e-01,   1.56391117e-02,   2.65041180e-02,
#         -9.95135743e-01,  -1.59995066e+01,   5.92082567e-06,
#          0.00000000e+00])
# Cost function after refinement: 9.14771917384e-09
# GonioParam(dist=0.64394475648168104, poni1=0.015639111692746385, poni2=0.026504117960154939, rot1_scale=-0.9951357427785279, rot1_offset=-15.999506576390978, rot2=5.9208256715106963e-06, rot3=0.0)
# maxdelta on: rot1_scale (3) -0.996093297296 --> -0.995135742779
# <div id='4e58820e-ae5e-4258-8607-90f0070b9dd9'></div>
# <div id='c55d48c2-8d9d-4c51-b4fa-5aaee9439079'></div>
# <div id='3b41dc2e-3bbb-4139-8f3f-e98647337792'></div>
# <div id='4ab5f3e3-7714-40be-8070-944987c5042c'></div>
# <div id='b5663513-be15-4464-b9c9-97f292c49103'></div>
# <div id='d2108951-4c4b-4d18-a05b-11b068ca9eb2'></div>
# <div id='beac604f-16e3-414a-aff7-a7b7c8d44de9'></div>
# <div id='a1ea96df-ac93-4898-95c2-b2803b539a6c'></div>

# %%
# plot the full diffractogram

def f(img: ndarray) -> ndarray:
    img = numpy.where(img > 20000, 0, img)
    return img

integrate(json, params, f, plot_calibrant=True)
# Out:
# <div id='ee3db7da-b51e-4b44-8cf2-f3f2008bb6a6'></div>

# %% [markdown]
# ## Integration <a name="integration"></a>

# %%
# integrate all the diffractogram

# let's take all the images
def to_use_sample(frame: CalibrationFrame) -> bool:
    return True


def mkCalibration(i: int) -> Calibration:
    return Calibration(os.path.join(PUBLISHED, "xrd", "calibration"),
                       os.path.join(ROOT, "2018-03-21", "TPHercules_{:d}.nxs".format(i)),
                       DatasetPathWithAttribute("interpretation", b"image"),
                       DatasetPathContains("scan_data/actuator_1_1"),
                       [1],
                       to_use_sample,
                       Calibrant("CeO2"),
                       Detector("imxpad_s140"),
                       Wavelength(6.8877e-11),
                       functions
                       )

tincrease = [mkCalibration(i) for i in range(113, 235)]
rtback = [mkCalibration(i) for i in range(243, 248)]
water = [mkCalibration(i) for i in range(253, 255)]
water2 = [mkCalibration(i) for i in range(256, 297)]
other = [mkCalibration(i) for i in [7, 300, 10, 11, 301, 299, 298]]

def f(img: ndarray) -> ndarray:
    img = numpy.where(img > 20000, 0, img)
    return img

samples = water + water2 + tincrease + rtback + other

for s in samples:
    print(s.filename)
    integrate(json, s, f, save=True)
# Out:
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_253.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_254.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_256.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_257.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_258.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_259.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_260.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_261.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_262.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_263.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_264.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_265.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_266.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_267.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_268.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_269.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_270.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_271.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_272.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_273.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_274.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_275.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_276.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_277.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_278.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_279.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_280.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_281.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_282.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_283.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_284.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_285.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_286.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_287.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_288.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_289.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_290.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_291.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_292.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_293.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_294.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_295.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_296.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_113.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_114.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_115.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_116.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_117.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_118.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_119.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_120.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_121.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_122.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_123.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_124.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_125.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_126.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_127.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_128.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_129.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_130.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_131.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_132.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_133.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_134.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_135.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_136.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_137.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_138.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_139.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_140.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_141.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_142.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_143.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_144.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_145.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_146.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_147.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_148.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_149.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_150.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_151.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_152.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_153.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_154.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_155.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_156.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_157.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_158.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_159.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_160.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_161.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_162.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_163.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_164.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_165.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_166.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_167.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_168.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_169.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_170.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_171.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_172.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_173.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_174.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_175.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_176.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_177.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_178.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_179.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_180.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_181.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_182.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_183.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_184.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_185.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_186.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_187.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_188.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_189.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_190.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_191.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_192.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_193.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_194.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_195.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_196.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_197.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_198.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_199.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_200.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_201.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_202.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_203.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_204.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_205.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_206.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_207.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_208.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_209.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_210.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_211.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_212.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_213.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_214.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_215.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_216.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_217.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_218.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_219.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_220.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_221.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_222.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_223.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_224.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_225.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_226.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_227.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_228.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_229.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_230.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_231.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_232.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_233.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_234.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_243.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_244.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_245.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_246.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_247.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_7.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_300.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_10.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_11.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_301.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_299.nxs
# /nfs/ruche-diffabs/diffabs-soleil/com-diffabs/2018/Run2/2018-03-21/TPHercules_298.nxs
